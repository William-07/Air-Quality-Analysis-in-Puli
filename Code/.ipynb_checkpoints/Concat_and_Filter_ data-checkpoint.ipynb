# %%
import pandas as pd 
import numpy as np
import os

#concate all csv file
#Get the list of all files
path = '/Users/shenglienlee/Desktop/GitHub/Air-Quality-Analysis-in-Puli/Data/All_Data'
data_files = os.listdir(path)
if '.DS_Store' in data_files:
    data_files.remove('.DS_Store')
#append all the data in the df_list
df_list = []
for i in data_files:
    df_list.append(pd.read_csv(path + "/" + i))
#Turn into Pandas dataframe
Original_data = pd.concat(df_list, ignore_index=True)

#filter out the data containing "埔里" ("Puli")
mask = Original_data["SiteName"] == "埔里"
#Sort Data by time
Hourly_Air_Data = Original_data[mask].sort_values(by = "DataCreationDate")
#reset the index
Hourly_Air_Data = Hourly_Air_Data.reset_index(drop=True)
#Export Data
Hourly_Air_Data.to_csv(r'/Users/shenglienlee/Desktop/GitHub/Air-Quality-Analysis-in-Puli/Data/Puli_Data/Hourly_Air_Data.csv', index = False,encoding='utf_8_sig')
Hourly_Air_Data
# Out:
#         SiteName County    AQI Pollutant   Status  SO2    CO   O3 O3_8hr  \
# 578214        埔里    南投縣  106.0     細懸浮微粒  對敏感族群不良  3.7  0.61   17   40.0
# 578221        埔里    南投縣  115.0     細懸浮微粒  對敏感族群不良  2.6  0.72  5.9   31.0
# 578308        埔里    南投縣  125.0     細懸浮微粒  對敏感族群不良  2.5  0.67  5.2   23.0
# 578380        埔里    南投縣  127.0     細懸浮微粒  對敏感族群不良  2.4  0.56  5.5   16.0
# 578543        埔里    南投縣  127.0     細懸浮微粒  對敏感族群不良  1.7  0.54  4.3   12.0
# ...          ...    ...    ...       ...      ...  ...   ...  ...    ...
# 2410158       埔里    南投縣   68.0     細懸浮微粒       普通  1.6  0.29   11     13
# 2410243       埔里    南投縣   71.0     細懸浮微粒       普通  1.6  0.31  9.2     12
# 2410340       埔里    南投縣   71.0     細懸浮微粒       普通  1.6  0.31  9.2     12
# 2410498       埔里    南投縣   72.0     細懸浮微粒       普通  1.5  0.28  9.7     11
# 2410413       埔里    南投縣   72.0     細懸浮微粒       普通  1.5  0.28  9.7     11
#
#          PM10  ... WindDirec  DataCreationDate  Unit  CO_8hr PM2.5_AVG  \
# 578214   73.0  ...     169.0  2017-01-01 00:00   NaN     0.6      37.0
# 578221   80.0  ...     228.0  2017-01-01 01:00   NaN     0.7      41.0
# 578308   85.0  ...     281.0  2017-01-01 02:00   NaN     0.7      45.0
# 578380   75.0  ...     245.0  2017-01-01 03:00   NaN     0.7      46.0
# 578543   67.0  ...     249.0  2017-01-01 04:00   NaN     0.7      46.0
# ...       ...  ...       ...               ...   ...     ...       ...
# 2410158    41  ...       320  2020-12-31 21:00   NaN     0.3      22.0
# 2410243    42  ...       311  2020-12-31 22:00   NaN     0.3      24.0
# 2410340    42  ...       311  2020-12-31 22:00   NaN     0.3      24.0
# 2410498    43  ...       314  2020-12-31 23:00   NaN     0.3      24.0
# 2410413    43  ...       314  2020-12-31 23:00   NaN     0.3      24.0
#
#         PM10_AVG SO2_AVG   Longitude   Latitude  SiteId
# 578214      65.0     NaN         NaN        NaN     NaN
# 578221      67.0     NaN         NaN        NaN     NaN
# 578308      72.0     NaN         NaN        NaN     NaN
# 578380      75.0     NaN         NaN        NaN     NaN
# 578543      75.0     NaN         NaN        NaN     NaN
# ...          ...     ...         ...        ...     ...
# 2410158       37     1.0  120.967903  23.968842    72.0
# 2410243       39     2.0  120.967903  23.968842    72.0
# 2410340       39     2.0  120.967903  23.968842    72.0
# 2410498       40     2.0  120.967903  23.968842    72.0
# 2410413       40     2.0  120.967903  23.968842    72.0
#
# [35684 rows x 25 columns]
